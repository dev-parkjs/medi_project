# %%
from functools import reduce
from pyspark.sql import SparkSession, Row
from pyspark.sql.types import StructType, StructField, StringType
from pyspark.sql.functions import col, coalesce, split, regexp_replace, when, length, get_json_object, explode, expr, concat_ws, array_contains,trim,substring,size,regexp_extract,flatten,array

# %%
spark = SparkSession.builder \
    .appName("medi_test") \
    .getOrCreate()
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 23/12/06 16:14:14 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
root_path = '/Users/parkjisook/Desktop/yeardream/medistream/js'
json_root_path = f'{root_path}/new_json/naverplace_meta'
save_root_path = f'{root_path}/new_json/output'
text_root_path = f'{root_path}/new_json/test.txt'

# %%
chunk_size = 100
test_json_path = f'{json_root_path}/naverplace_meta_1.json'

# %%
# df = spark.read.option("multiline", "true").json('/Users/parkjisook/Desktop/yeardream/medistream/js/new_json/naverplace_meta/naverplace_meta_1.json')
df = spark.read.json('/Users/parkjisook/Desktop/yeardream/medistream/js/new_json/naverplace_meta/naverplace_meta_1.json')
# Out:
# 23/12/06 16:14:17 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.

# %%
df_exploded = df.select(explode("Hospital").alias("HospitalData"))
df_exploded_2 = df.select(explode("ROOT_QUERY").alias("ROOT_QUERY_Data"))

# %%
df_result_2 = df_exploded_2.select(
    regexp_extract(col("ROOT_QUERY_Data.hospital.base.__ref"), 'HospitalBase:(\\d+)', 1).alias("id2"),
    col("ROOT_QUERY_Data.hospital.fsasReviews.total").alias("fsas_reviews_count"),
    col("ROOT_QUERY_Data.hospital.kinQna.answerCount").alias("answerCount")
)

# %%
df_result = df_exploded.select(
    col("HospitalData.id").alias("id"),
    col("HospitalData.name").alias("name"),
    col("HospitalData.reviewSettings.keyword").alias("review_keyword"),
    col("HospitalData.description").alias("description"),
    col("HospitalData.road").alias("road"),
    col("HospitalData.bookingBusinessId").alias("booking_business_id"),
    col("HospitalData.bookingDisplayName").alias("booking_display_name"),
    col("HospitalData.category").alias("category"),
    col("HospitalData.categoryCode").alias("category_code"),
    col("HospitalData.categoryCount").alias("category_count"),
    col("HospitalData.rcode").alias("rcode"),
    col("HospitalData.virtualPhone").alias("virtual_phone"),
    col("HospitalData.phone").alias("hospital_phone"),
    col("HospitalData.naverBookingUrl").alias("naver_booking_url"),
    col("HospitalData.conveniences").alias("conveniences_str"),
    col("HospitalData.talktalkUrl").alias("talktalk_url"),
    col("HospitalData.roadAddress").alias("road_address"),
    col("HospitalData.keywords").alias("hospital_keywords_str"),
    col("HospitalData.paymentInfo").alias("payment_info_str"),
    col("HospitalData.coordinate.x").alias("lon"),
    col("HospitalData.coordinate.y").alias("lat"),
    col("HospitalData.homepages.etc.url").alias("homepages_url_str"),
    col("HospitalData.homepages.etc.landingUrl").alias("homepages_landingUrl_str"),
    col("HospitalData.homepages.etc.type").alias("homepages_type_str"),
    col("HospitalData.homepages.etc.order").alias("homepages_order_str"),
    col("HospitalData.homepages.etc.isDeadUrl").alias("homepages_isDeadUrl_str"),
    col("HospitalData.homepages.etc.isRep").alias("homepages_isRep_str"),
    col("HospitalData.visitorReviewsTotal").alias("visitor_Reviews_Total"),
    col("HospitalData.visitorReviewsScore").alias("visitor_Reviews_Score"),
    col("HospitalData.visitorReviewsTextReviewTotal").alias("visitor_Reviews_Text_Review_Total"),
    col("HospitalData.images").alias("images")
)

# %%
deduplicated_df = df_result.dropDuplicates([
    "id",
    "name",
    "booking_business_id",
    "booking_display_name",
    "category",
    "category_code",
    "category_count",
    "description",
    "road",
    "rcode",
    "virtual_phone",
    "hospital_phone",
    "naver_booking_url",
    "conveniences_str",
    "talktalk_url",
    "road_address",
    "hospital_keywords_str",
    "payment_info_str",
    "lon",
    "lat",
    "homepages_url_str",
    "homepages_landingUrl_str",
    "homepages_type_str",
    "homepages_order_str",
    "homepages_isDeadUrl_str",
    "homepages_isRep_str",
    "visitor_Reviews_Total",
    "visitor_Reviews_Score",
    "visitor_Reviews_Text_ReviewTotal",
    "images"
])

# %%
# deduplicated_df = deduplicated_df.withColumn("conveniences", concat_ws(",", "conveniences_str")) \
#                       .withColumn("hospital_keywords", concat_ws(",", "hospital_keywords_str")) \
#                       .withColumn("payment_info", concat_ws(",", "payment_info_str")) \
#                       .drop("conveniences_str", "hospital_keywords_str", "payment_info_str")

# %%
# 열을 콤마로 구분된 문자열로 변환
deduplicated_df = deduplicated_df.withColumn("conveniences", concat_ws(",", "conveniences_str"))
deduplicated_df = deduplicated_df.withColumn("hospital_keywords", concat_ws(",", "hospital_keywords_str"))
deduplicated_df = deduplicated_df.withColumn("payment_info", concat_ws(",", "payment_info_str"))
deduplicated_df = deduplicated_df.withColumn("homepages_url", concat_ws(",", "homepages_url_str"))
deduplicated_df = deduplicated_df.withColumn("homepages_landingUrl", concat_ws(",", "homepages_landingUrl_str"))
deduplicated_df = deduplicated_df.withColumn("homepages_type", concat_ws(",", "homepages_type_str"))
deduplicated_df = deduplicated_df.withColumn("homepages_order", concat_ws(",", "homepages_order_str"))
deduplicated_df = deduplicated_df.withColumn("homepages_isDeadUrl", concat_ws(",", "homepages_isDeadUrl_str"))
deduplicated_df = deduplicated_df.withColumn("homepages_isRep", concat_ws(",", "homepages_isRep_str"))

# 더 이상 필요하지 않은 중간 열 삭제
deduplicated_df = deduplicated_df.drop("conveniences_str", 
                                       "hospital_keywords_str", 
                                       "payment_info_str", 
                                       "homepages_url_str",
                                       "homepages_landingUrl_str",
                                       "homepages_type_str",
                                       "homepages_order_str",
                                       "homepages_isDeadUrl_str",
                                       "homepages_isRep_str")

# %%
deduplicated_df = deduplicated_df.withColumn(
    'description',
    regexp_replace(
        trim(
            when(col('description').isNotNull(), col('description'))
        ),
        '\n|\r|\*|,',
        ' '
    )
)

# %%
deduplicated_df = deduplicated_df.withColumn(
    'road',
    regexp_replace(
        trim(
            when(col('road').isNotNull(), col('road'))
        ),
        '\n|\r|\*|,',
        ' '
    )
)

# %%
deduplicated_df = deduplicated_df.withColumn(
    'review_keyword',
    regexp_replace(
        trim(
            when(col('review_keyword').isNotNull(), col('review_keyword'))
        ),
        r'["\\]',
        ''
    )
)

# %%
deduplicated_df = deduplicated_df.withColumn("image_count", size(col("images")))
deduplicated_df = deduplicated_df.drop("images")

# %%
#is_smart_phone
deduplicated_df = deduplicated_df.withColumn(
    'is_smart_phone',
    when(
        col('virtual_phone').isNotNull() & col('virtual_phone').startswith('010'),
        True
    ).otherwise(False)
)

# %%
# payment_info & zero_pay
deduplicated_df = deduplicated_df.withColumn(
    'zero_pay',
    col('payment_info').contains('제로페이')
)

# %%
#is_blog_exposed
deduplicated_df = deduplicated_df.withColumn(
    'is_blog_exposed',
    col('homepages_type').contains('블로그')
)

# %%
#keywords
deduplicated_df = deduplicated_df.withColumn(
    'keywords_array',
    split(col('hospital_keywords'), ',')
)

deduplicated_df = deduplicated_df.withColumn(
    'keywords_1', col('keywords_array')[0]
).withColumn(
    'keywords_2', col('keywords_array')[1]
).withColumn(
    'keywords_3', col('keywords_array')[2]
).withColumn(
    'keywords_4', col('keywords_array')[3]
).withColumn(
    'keywords_5', col('keywords_array')[4]
)

deduplicated_df = deduplicated_df.drop('keywords_array')

# %%
#hospital_description_length
deduplicated_df = deduplicated_df.withColumn('description_length', length('description'))

# %%
#photo_review_ratio
deduplicated_df = deduplicated_df.withColumn(
    'photo_review_ratio',
    (col('visitor_Reviews_Total') - col('visitor_Reviews_Text_Review_Total')) / col('visitor_Reviews_Total')
)

# %%
joined_df = deduplicated_df.join(df_result_2, deduplicated_df.id == df_result_2.id2, "inner")

# %%
selected_columns = [
    "id", 
    "name", 
    "review_keyword",    
    "hospital_keywords",
    "keywords_1", "keywords_2","keywords_3", "keywords_4", "keywords_5", 
    "photo_review_ratio",
    "image_count",
    "naver_booking_url", "talktalk_url",
    "road",
    "road_address", "lon", "lat", 
    "hospital_phone", 
    "virtual_phone","is_smart_phone",
    "homepages_url", "homepages_landingUrl", "homepages_type",
    "homepages_order", "homepages_isDeadUrl", "homepages_isRep", 
    "is_blog_exposed",
    "payment_info",  "zero_pay",
    "conveniences", 
    "description", "description_length",
    "answerCount",
    "booking_business_id",
    "booking_display_name", 
    "category", "category_code", "category_count",
    "rcode", 
    "visitor_Reviews_Total", "visitor_Reviews_Score","visitor_Reviews_Text_Review_Total",
    "fsas_reviews_count"
]
    

result_df = joined_df.select(*selected_columns)

# 결과 확인
result_df.show(truncate=False)
# Out:
# +----------+------------------+-------------------------------------------------------------------------+--------------------------------------------------------------------------+---------------+----------------------+------------------+------------+----------------+-------------------+-----------+---------------------------------------------------+-------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------------------------------------------------------+------------------+-----------------+--------------+--------------+--------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------+---------------+-----------------------------+---------------+---------------+-----------------------------------+--------+-------------------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# |id        |name              |review_keyword                                                           |hospital_keywords                                                         |keywords_1     |keywords_2            |keywords_3        |keywords_4  |keywords_5      |photo_review_ratio |image_count|naver_booking_url                                  |talktalk_url                         |road                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |road_address                                                         |lon               |lat              |hospital_phone|virtual_phone |is_smart_phone|homepages_url                                                                                                                                                                     |homepages_landingUrl                                                                                                                                                              |homepages_type                          |homepages_order|homepages_isDeadUrl          |homepages_isRep|is_blog_exposed|payment_info                       |zero_pay|conveniences                                           |description                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        ...
# +----------+------------------+-------------------------------------------------------------------------+--------------------------------------------------------------------------+---------------+----------------------+------------------+------------+----------------+-------------------+-----------+---------------------------------------------------+-------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------------------------------------------------------+------------------+-----------------+--------------+--------------+--------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------+---------------+-----------------------------+---------------+---------------+-----------------------------------+--------+-------------------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# |19997932  |강남신사한의원    |(강남신사한의원) & (강남구 | 신사동 | 한의원-일반) & 강남신사한의원      |                                                                          |               |NULL                  |NULL              |NULL        |NULL            |0.23809523809523808|6          |NULL                                               |NULL                                 |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             |서울 강남구 강남대로156길 24 유진빌딩 2층                            |127.0211036       |37.5184006       |02-3445-0075  |              |false         |                                                                                                                                                                                  |                                                                                                                                                                                  |                                        |               |                             |               |false          |제로페이                           |true    |                                                       |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ...
# |1792527632|견우한의원        |(견우한의원) & (마포구 | 공덕동 | 한의원-일반) & 견우한의원              |어깨통증,목통증,팔꿈치통증,손목통증,공덕한의원                            |어깨통증       |목통증                |팔꿈치통증        |손목통증    |공덕한의원      |0.09887869520897044|50         |NULL                                               |NULL                                 |공덕역 5번 출구로 나와 그대로 직진하면  하얀색 16층 제일빌딩이 보이고  2층에 오면 한의원이 3개가 있는데  견우한의원으로 오면 됩니다.  주차는 제일빌딩 1층이나 지하에 하면 되고  초진은 1시간  재진은 30분 무료 주차 가능합니다.                                                                                                                                                                                                                                                                                                                                                                                                              |서울 마포구 만리재로 15 제일빌딩 208호                               |126.9527595       |37.5445786       |02-703-9754   |              |false         |https://blog.naver.com/a0119754,http://cafe.naver.com/gwomc,http://www.gyeonwoo.net,http://www.facebook.com/profile.php?id=100009814564277,http://www.instagram.com/gyeonwoo_mapo/|https://blog.naver.com/a0119754,http://cafe.naver.com/gwomc,http://www.gyeonwoo.net,http://www.facebook.com/profile.php?id=100009814564277,http://www.instagram.com/gyeonwoo_mapo/|블로그,카페,웹사이트,페이스북,인스타그램|1,2,3,4,5      |false,false,false,false,false|               |true           |지역화폐(지류,카드,모바일),제로페이|true    |주차,예약,남/녀 화장실 구분                            |안녕하십니까~! 어깨가 아프면 견우한의원입니다.  왜 어깨가 아프면 견우한의원일까요? 어깨 치료를 위해 연구하고 또 연구하기 때문입니다. 근거 중심의 치료를 환자에게 제공하기 위해서 논문  특허  책을 꾸준히 출간하고 있습니다. 2023년 7월 기준으로 논문은 SCI급 논문을 비롯해 국내외에 10건  특허는 1건  책은 4권을 출간했습니다.  대한민국에 실력 좋고 유명한 한의원이 많은데 왜 멀리서도 이곳을 찾아주시는 걸까요? 제대로 치료하지 못할거라면 처음부터 시작하지 않으며 환자 증상에 맞는 치료를 고집하기 때문입니다.  왜 지인 소개가 많을까요? 효과를 본 환자들이 자신들이 경험한 생생한 치료 경험을 나누기 때문입니다.  왜 치료 시간이 짧을까요? 자침 후 돌린 다음 바로 빼는 염전 치료법을 사용해 초진은 20~30분 전후  재진은 5분 전후로 치료가 끝나게 됩니다.  왜 한의원 이름이 견우(肩友)인가요? 어깨 견 벗 우 우리말로 풀어 쓰면 어깨 친구가 됩니다. 여러분의 어깨를 먼저 생각하는 믿음직한 어깨 친구가 되고자 하는 저의 진심에서 나온 이름입니다.  치료비는 얼마인가요? 2023년 9월 기준으로 초진 치료비는 7-8천원 전후하며 재진은 3-4천원 전후하고 봉약침은 2~3만원 필요한 경우 한약을 처방하기도 하는데 한약은 한달 기준으로 42만원입니다.  어떻게 치료하나요? 침과 봉약침 위주로 치료하고 필요한 경우 한약을 처방하기도 하며 불필요한 진료는 하지 않습니다.  치료 시간은 얼마나 걸리나요? 초진은 상담 시간이 있어 20~30분 전후  재진은 5분 전후로 끝이 납니다. 초진인 경우 벌써 끝났어요 라는 말이 나올 정도로 치료 시간이 짧습니다.  치료 시간이 왜 짧은가요? 침을 꽂아 놓지 않고 자침한 다음 돌리고 바로 빼는 염전 치료를 하기 때문입니다.  침을 돌리면 아프지 않나요? 얇은 침을 사용해 자침하기에 일반 주사와 비슷한 정도 혹은 그 이하라고 보면 됩니다.  사보험 적용이 되나요? 보험사와 보험마다 달라 본인이 확인해 보셔야 합니다. 보험사에 전화해서 견우한의원에 왔는데 여기서 침  약침  한약 치료를 하자고 하는데 내 보험이 되나요? 된다고 하면 총액은 얼마인지  일일 한도는 얼마인지 물어보면 됩니다.  2010년 국내 최초 오십견의 날 지정(5월 10일)  2011년 국내 최초 일자목의 날 지정(1월 1일)  성균관대학교 약학대학 약학과 졸업 : 약사  한약조제사  가천대학교 한의과대학 한의학과 차석 졸업 : 한의사  한의학박사  고촌장학생(종근당 고촌재단)  대한한방견주관절학회 회장  가천대 한의대 교수 역임  숙대 약대 교수 역임  연구 협약 체결 : 가천대 한의대 예방의학교실  성대 의대 줄기세포분화연구실  숙대 약대 분화발생연구실  단대 약대 독성학연구실  자신있는 치료만 진행할 것을 약속드립니다.  여러분의 궁금증이 충분히 해소되었고 내 소중한 어깨를 맡겨도 되겠다는 믿음이 서는 분이라면 언제든 내원하셔도 좋습니다.  건강하세요~!                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           |1460              |334        |NULL               |방문                |한의원  |223265       |2             |09440102|981                  |4.89                 |884                              |1287              |
# |19534198  |경동한의원        |(경동한의원) & (동대문구 | 제기동 | 한의원-일반) & 경동한의원            |                                                                          |               |NULL                  |NULL              |NULL        |NULL            |0.5                |0          |NULL                                               |NULL                                 |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             |서울 동대문구 약령동길 41                                            |127.0377695       |37.5801906       |02-962-2111   |              |false         |                                                                                                                                                                                  |                                                                                                                                                                                  |                                        |               |                             |               |false          |                                   |false   |                                                       |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        ...
# |1955472527|경리단길한의원    |(경리단길한의원) & (용산구 | 이태원동 | 한의원-일반) & 경리단길한의원    |이태원한의원,녹사평한의원,이태원교통사고,이태원추나,이태원다이어트        |이태원한의원   |녹사평한의원          |이태원교통사고    |이태원추나  |이태원다이어트  |0.3333333333333333 |2          |NULL                                               |NULL                                 |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             |서울 용산구 회나무로6길 5 3층                                        |126.9888231       |37.5387393       |02-749-1075   |              |false         |                                                                                                                                                                                  |                                                                                                                                                                                  |                                        |               |                             |               |false          |지역화폐(모바일),제로페이          |true    |주차,무선 인터넷,남/녀 화장실 구분                     |주민들의 건강문제를 함께 고민하고 돌보는 동네한의원  [척추 관절 클리닉] 급성 염좌  관절염  건초염  디스크  협착증 등 척추 관절 질환으로 인한 통증 개선  [교통사고 후유증 클리닉] 교통사고로 인한 각 종 손상 및 두통  가슴 두근거림  불안  긴장감 등의 개선  [피로회복 클리닉] 스트레스 및 불면 등으로 인한 만성 피로 회복 및 면역력 강화  [다이어트 클리닉] 개인별 맞춤 처방 및 생활 습관 티칭  방문하는 모든 분들의 건강을 기원합니다 :)  Welcome to Dr.Gil's Korean Medicine Clinic. We provide traditional medical services for local residents. English-speaking doctor  specialize in acupuncture and herbal medicine.  经理团路韩医院提供优质韩医(中医)内科  针灸及推拿门诊服务.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   ...
# |18045152  |경안한약방        |(경안한약방) & (동대문구 | 제기동 | 한의원-일반) & 경안한약방            |                                                                          |               |NULL                  |NULL              |NULL        |NULL            |0.6                |0          |NULL                                               |NULL                                 |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             |서울 동대문구 약령서길 16                                            |127.036286        |37.57908000091209|02-965-6668   |              |false         |                                                                                                                                                                                  |                                                                                                                                                                                  |                                        |               |                             |               |false          |                                   |false   |                                                       |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        ...
# |12824173  |경희궁의봄한의원  |(경희궁의봄한의원) & (마포구 | 도화동 | 한의원-일반) & 경희궁의봄한의원  |난임,습관성유산,시험관전준비,만성피로,체질개선                            |난임           |습관성유산            |시험관전준비      |만성피로    |체질개선        |0.3620689655172414 |8          |https://m.booking.naver.com/booking/13/bizes/508574|NULL                                 |5호선-마포역 3번 출구 5호선/6호선/공항철도/경의중앙선역-공덕역 8번 출구                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      |서울 마포구 마포대로 68 마포아크로타워                               |126.94898         |37.5413405       |02-717-8275   |              |false         |https://blog.naver.com/khgungbom,http://gungbom.com,https://www.instagram.com/gungbom                                                                                             |https://blog.naver.com/khgungbom,http://gungbom.com,https://www.instagram.com/gungbom                                                                                             |블로그,웹사이트,인스타그램              |1,2,3          |false,false,false            |               |true           |지역화폐(카드,모바일),제로페이     |true    |주차,무선 인터넷,남/녀 화장실 구분                     | 체질개선과 음식처방으로 여성질환과 함께   다양한 만성질환을 치료하는 한의원   여성한의원에서 온가족이 믿고 찾는   가족한의원으로 진료과목을 확대합니다.    진료과목   체질개선/음식치료   난임/습관성유산/자궁질환   산후조리/산후비만   비염/난치성피부질환(아토피 두드러기)   불면증/만성두통/이명/난청/만성피로   통증/복부비만/전신비만 등 치료  ..........................................................................  윤영진 대표원장   경희대학교 한의학과 졸업   경희대학교 한의학 석사   경희대학교 한의학 박사  ..........................................................................  위치   5호선- 마포역 3분 거리   5/6호선/공항철도- 공덕역 3분거리   진료시간   월/금 오전 10시~오후 5시까지   화/목 오전 10시~오후 8시 30분까지(야간진료)   수요일 매주 휴진   토요일 오전 10시~오후 3시   일요일/공휴일 휴진    점심시간 오후 2시~오후 3시  ..........................................................................  상담/예약문의   02-717-8275(예약제 운영)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         ...
# |19520846  |경희노들한의원    |(경희노들한의원) & (동작구 | 본동 | 한의원-일반) & 경희노들한의원        |한의원,노들역,노량진,본동,동작구                                          |한의원         |노들역                |노량진            |본동        |동작구          |0.39473684210526316|1          |NULL                                               |NULL                                 |9호선 노들역 5번 출구로 나오셔서 바로 좌측 신양빌딩 2층입니다.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               |서울 동작구 매봉로 182 신양빌딩                                      |126.95240800000201|37.5124210000044 |02-812-5675   |              |false         |                                                                                                                                                                                  |                                                                                                                                                                                  |                                        |               |                             |               |false          |지역화폐(카드,모바일),제로페이     |true    |주차,무선 인터넷,남/녀 화장실 구분                     |친절하고 정성을 다하는 '경희노들한의원'  한방내과전문의가 진료합니다.  각종 통증 질환  내과 질환 및 소아과  부인과 진료  교통사고 후유증을 전문으로 진료합니다.  서울 9호선 노들역 5번 출구 바로 앞에 위치합니다.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# |1049624743|경희닥터권한의원  |(경희닥터권한의원) & (마포구 | 공덕동 | 한의원-일반) & 경희닥터권한의원  |ADHD,소아한의원,성장,비염,틱                                              |ADHD           |소아한의원            |성장              |비염        |틱              |0.0                |9          |NULL                                               |http://talk.naver.com/w42430?frm=mnmb|공덕역 3번출구로 나오셔서 300m 직진 버스 이용시 (아현동 주민센터 정류장 하차) 마을버스 - 마포10 일반버스 - 1002 지선버스 - 7013A  7611  7013A 간선버스 - 260  160  600 광역버스 - 2500 공항버스 - 6015                                                                                                                                                                                                                                                                                                                                                                                                                                       |서울 마포구 마포대로 143 파크팰리스2 209호                           |126.9530883       |37.5474434       |02-3275-1311  |              |false         |https://blog.naver.com/khdrkwon                                                                                                                                                   |https://blog.naver.com/khdrkwon                                                                                                                                                   |블로그                                  |1              |false                        |               |true           |                                   |false   |주차,예약,남/녀 화장실 구분                            |현재 휴진중이며 이전개원 예정입니다.  한의학 박사 권선근 원장이 진료하는 경희닥터권 한의원 입니다. 경희대 본초학 박사로 엄마들이 안심하고 먹일 수 있는 탕약은 물론  정기적인 직원교육으로 언제나 만족스러운 진료 서비스를 선보이겠습니다.  소아와 청소년들의 감기  아토피  비염  축농증  중이염  천식  장염  틱  ADHD  학습부진  비만  성장  성조숙 등의 잦은 질환  허약한 아이들의 면역력 향상  임산부의 산전산후 건강관리  직장인의 만성피로  다이어트  우울증의 관리를 도와드리겠습니다.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ...
# |13104773  |경희당한의원      |(경희당한의원) & (동작구 | 상도동 | 한의원-일반) & 경희당한의원          |약침한의원,교통사고치료,한약,통증,추나                                    |약침한의원     |교통사고치료          |한약              |통증        |추나            |0.20279720279720279|16         |NULL                                               |NULL                                 |상도1동 동사무소(구 상도 5동 동사무소) 옆 상도 래미안 3차 단지 내 상가에 위치.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               |서울 동작구 상도로53길 13 래미안상도3차아파트                        |126.952899        |37.498528        |02-826-7900   |              |false         |                                                                                                                                                                                  |                                                                                                                                                                                  |                                        |               |                             |               |false          |제로페이                           |true    |                                                       |상도동 숭실대 옆 상도래미안3차 단지상가에 위치한 경희당한의원입니다. 아프고 힘들어 찡그린 여러분들에게 미소를 찾아 드리고 싶은 그런 곳입니다.  목  어깨  허리  팔다리 등 근골격계 통증은 초음파진단기 및 이학적검사를 통한 정확한 진단과 더불어 침  약침  추나  물리치료 및 한약치료를 통해 해결하고...  신체내부의 문제로 발생하는 피로  소화기나 호흡기 문제  부인과 질환  정서적인 문제 등은 맥진  설진  문진 및 인바디  혈액검사 등을 통해 꼼꼼히 분석해서 침  한약  상담 등을 통해 최선을 다해 치료해 드리겠습니다.  아픔을 공감하며 실력과 더불어 마음으로 치료하겠습니다... ^^                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ...
# ...
# |1632024740|경희수진한의원    |(경희수진한의원) & (용산구 | 이촌동 | 한의원-일반) & 경희수진한의원      |용산비만한의원,용산소아한의원,용산탈모한의원,용산공진단,이촌한의원        |용산비만한의원 |용산소아한의원        |용산탈모한의원    |용산공진단  |이촌한의원      |0.3                |5          |NULL                                               |NULL                                 |이촌역 3-1번출구에서 직진후 좌회전->카모메식당에서 우회전-> 파리크라상에서 좌회전하시면 신용산 초등학교 맞은편 삼익상가 2층(베스킨라빈스위)   주차: 삼익상가 뒤 삼익아파트 주차장내 주차                                                                                                                                                                                                                                                                                                                                                                                                                                                     |서울 용산구 이촌로 264 삼익상가 2층 206호                            |126.9761401       |37.5190282       |02-793-8275   |              |false         |https://kyungheesujin.modoo.at/                                                                                                                                                   |https://kyungheesujin.modoo.at/                                                                                                                                                   |모두                                    |1              |false                        |               |false          |제로페이                           |true    |주차,예약,무선 인터넷                                  |경희수진한의원은 수많은 경험과 전문지식을 기반으로 하여 다양한 진료를 통해 환자 개개인을 위한 맞춤형 진료를 지향합니다.  통증진료와 다양한 물리치료외에 비만  소아감기 및 성장  여드름및 정안침  두피염증및 탈모  비염 치료에 대한 시스템이 갖추어져 있습니다. 우리 아이들  우리 가족들이 받을 수 있는 올바르고 정직한 진료를 하기 위해 노력하고 있습니다.   책임감 있는 진료를 통해 믿음직스러운 가족주치의가 되겠습니다.  편안하고 아늑한 공간에서 진료 받으시고 소망하시는 일  모두 이루시기를 바랍니다.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...
# |13157277  |경희약손한의원    |(경희약손한의원) & (동작구 | 상도동 | 한의원-일반) & 경희약손한의원      |만성피로_공진단,수험생_총명탕,소아성장,교통사고,통증치료                  |만성피로_공진단|수험생_총명탕         |소아성장          |교통사고    |통증치료        |0.208955223880597  |0          |NULL                                               |NULL                                 |상도역 3번 출구 100m 직진  상도노빌리티 상가(빽다방)에서 우회전 50m 직진  파리바게트 맞은편 건물 3층입니다. 엘리베이터 있습니다.  자가용 이용시 주소는 동작구 만양로11 대화빌딩 입니다. 주차는 페리카나치킨과 세븐일레븐 사이 골목에 위치한 대화빌딩 주차타워에 하시면 됩니다.                                                                                                                                                                                                                                                                                                                                                               |서울 동작구 만양로 11 대화빌딩                                       |126.946932        |37.505843        |02-821-5075   |              |false         |                                                                                                                                                                                  |                                                                                                                                                                                  |                                        |               |                             |               |false          |지역화폐(카드,모바일),제로페이     |true    |주차,예약,무선 인터넷,남/녀 화장실 구분                |일대일 맞춤한약과 정직한 진료를 약속드리는 경희약손한의원입니다. 본원 탕전실에서 원장님이 직접 조제하여 탕전합니다.  -체질보약/만성피로/산전산후조리/돌보약/성장보약/ -수험생/총명탕/공진단/경옥고/ -만성통증/담결림/근육통/관절통/염좌/자동차보험치료/교통사고후유증  <진 료 안 내> 월/화/수/금: 오전9시30분- 저녁7시 토요일: 오전9시30분-오후1시 (토요일 점심시간없이 진료) 목요일/일요일: 휴 진 점심시간: 12시30분-2시  오전진료접수마감: 12시30분                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    ...
# +----------+------------------+-------------------------------------------------------------------------+--------------------------------------------------------------------------+---------------+----------------------+------------------+------------+----------------+-------------------+-----------+---------------------------------------------------+-------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------------------------------------------------------+------------------+-----------------+--------------+--------------+--------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------+---------------+-----------------------------+---------------+---------------+-----------------------------------+--------+-------------------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# only showing top 20 rows

# %%
csv_output_path = f'{save_root_path}/deduplicated_output.csv'

result_df.write.csv(csv_output_path, header=True, mode='overwrite')

# %%
result_df.write.mode('overwrite').parquet(save_root_path)
